# %% [markdown]
# # Module 1 Assignment 1

# %% [markdown]
# # 3.1

# %%
60 * 60
# Out:
# 3600

# %% [markdown]
# # 3.2

# %%
seconds_per_hour = 3600

# %% [markdown]
# # 3.3

# %%
seconds_per_hour * 24
# Out:
# 86400

# %% [markdown]
# # 3.4

# %%
seconds_per_day = seconds_per_hour * 24

# %% [markdown]
# # 3.5

# %%
seconds_per_day / seconds_per_hour
# Out:
# 24.0

# %% [markdown]
# # 3.6

# %%
seconds_per_day // seconds_per_hour
# Out:
# 24

# %% [markdown]
# # Yes, the two operations agree with one another.
