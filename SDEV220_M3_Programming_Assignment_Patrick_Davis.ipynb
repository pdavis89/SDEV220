# %% [markdown]
# 7.4

# %%
things = ['mozzarella', 'cinderella', 'salmonella']

# %% [markdown]
# 7.5

# %%
things[1] = 'Cinderella'
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# Yes, it changed the list element.

# %% [markdown]
# 7.6

# %%
things[0] = 'MOZZARELLA'
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %% [markdown]
# 7.7

# %%
del things[-1]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']

# %% [markdown]
# 9.1

# %%
def good():
    return ['Harry', 'Ron', 'Hermione']

# %% [markdown]
# 9.2

# %%
def get_odds():
    for num in range(10):
        if num %2 == 1:
            yield num

count = 0
for value in get_odds():
    count += 1
    if count == 3:
        print(value)
        break
# Out:
# 5
