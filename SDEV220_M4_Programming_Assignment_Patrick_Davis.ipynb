# %% [markdown]
# 11.1

# %%
code = """
def hours():
    print('Open 9-5 daily')
"""

with open("zoo.py", "w") as f:
    f.write(code)

# %%
from zoo import hours

# %%
hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# 11.2

# %%
import zoo as menagerie

hours()
# Out:
# Open 9-5 daily

# %% [markdown]
# 16.8

# %%
import sqlalchemy
